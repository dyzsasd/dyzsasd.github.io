# %%
import tensorflow as tf  # 引入tensorflow库
from tensorflow.examples.tutorials.mnist import input_data  # 载入minist数据集
import numpy as np

mnist = input_data.read_data_sets(
    "MNIST_data/", one_hot=True, source_url="http://storage.googleapis.com/cvdf-datasets/mnist/")

images_train = mnist.train.images
images_test = mnist.test.images
labels_train = np.argmax(mnist.train.labels, axis=1)
labels_test = np.argmax(mnist.test.labels, axis=1)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(images_train)
dnn_clf = tf.estimator.DNNClassifier(
    hidden_units=[300, 100], n_classes=10, feature_columns=feature_columns)
dnn_clf.fit(x=images_train, y=labels_train, batch_size=50, steps=40000)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/1m/x1cf155n49ggfbknh6kyg6qr0000gp/T/tmpzzghtipg
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1217ecda0>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/var/folders/1m/x1cf155n49ggfbknh6kyg6qr0000gp/T/tmpzzghtipg'}
# ...

# %%
dnn_clf.evaluate(images_test, labels_test)
# Out:
# WARNING:tensorflow:From <ipython-input-14-ba09cf091225>:1: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-14-ba09cf091225>:1: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# ...
